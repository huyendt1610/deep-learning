# %%
# !pip install gensim # nlp libs
# !pip install python-Levenshtein
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --------------------------------- ------ 1.3/1.5 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 4.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
#    ---------------------------------------- 0/3 [rapidfuzz]
# ...

# %%
import gensim
import pandas as pd

# %% [markdown]
# ### Reading and Exploring the Dataset
#
# The Dataset used here is a subset of Amazon reviews from the Cell Phones & Accessories category. The data is stored as a JSON file and can be read using pandas
#
# Link:
# (http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Cell_Phones_and_Accessories_5.json.gz)

# %%
df = pd.read_json('datasets/Cell_Phones_and_Accessories_5.json', lines=True)
df.head(2)
# Out:
#        reviewerID        asin reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X    christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X     emily l.  [0, 0]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
#
#                  summary  unixReviewTime   reviewTime
# 0             Looks Good      1400630400  05 21, 2014
# 1  Really great product.      1389657600  01 14, 2014

# %%
df.shape
# Out:
# (194439, 9)

# %%
sample = df.reviewText[0]

# %%
gensim.utils.simple_preprocess(sample)
# Out:
# ['they',
#  'look',
#  'good',
#  'and',
#  'stick',
#  'good',
#  'just',
#  'don',
#  'like',
#  'the',
#  'rounded',
#  'shape',
#  'because',
#  'was',
#  'always',
#  'bumping',
#  'it',
#  'and',
#  'siri',
#  'kept',
#  'popping',
#  'up',
#  'and',
#  'it',
#  'was',
#  'irritating',
#  'just',
#  'won',
#  'buy',
#  'product',
#  'like',
#  'this',
#  'again']

# %%
review_text = df.reviewText.apply(gensim.utils.simple_preprocess) # tokenize all
review_text
# Out:
# 0         [they, look, good, and, stick, good, just, don...
# 1         [these, stickers, work, like, the, review, say...
# 2         [these, are, awesome, and, make, my, phone, lo...
# 3         [item, arrived, in, great, time, and, was, in,...
# 4         [awesome, stays, on, and, looks, great, can, b...
#                                 ...
# 194434    [works, great, just, like, my, original, one, ...
# 194435    [great, product, great, packaging, high, quali...
# 194436    [this, is, great, cable, just, as, good, as, t...
# 194437    [really, like, it, becasue, it, works, well, w...
# 194438    [product, as, described, have, wasted, lot, of...
# Name: reviewText, Length: 194439, dtype: object

# %%
model = gensim.models.Word2Vec(
    window=10, # 10 words before the target word and 10 words after
    min_count = 2, # min count of words to be considered as a sentence in training
    workers = 4 # threads number
)

# %%
model.build_vocab(
    review_text, 
    progress_per=1000, # how many words to process before showing/updating the progress
)

# %%
model.epochs
# Out:
# 5

# %%
model.corpus_count
# Out:
# 194439

# %%
model.train(review_text, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (61502422, 83868975)

# %%
model.save("savedmodel/word2vec-cellphone-review.short.model")

# %%
model.wv.most_similar("bad") # word to vec
# Out:
# [('terrible', 0.7051274180412292),
#  ('shabby', 0.621117115020752),
#  ('horrible', 0.6052618026733398),
#  ('good', 0.5842424631118774),
#  ('okay', 0.5626454949378967),
#  ('disappointing', 0.5490814447402954),
#  ('awful', 0.5431448221206665),
#  ('ok', 0.5410187840461731),
#  ('funny', 0.5233039259910583),
#  ('crappy', 0.5214327573776245)]

# %%
model.wv.similarity(w1="cheap", w2="inexpensive")
# Out:
# np.float32(0.54247737)

# %%
model.wv.similarity(w1="great", w2="good")
# Out:
# np.float32(0.78803384)

# %%
model.wv.similarity(w1="great", w2="item")
# Out:
# np.float32(-0.011809558)
